# %%
import pandas as pd

# %%
csmpo_df = pd.read_csv("csmpo_df.csv")
csmso_df = pd.read_csv("csmso_df.csv")
mipo_df = pd.read_csv("mipo_df.csv")
miso_df = pd.read_csv("miso_df.csv")

final_df = (
    csmpo_df[["Unnamed: 0", "query", "market_type", "query_level", "product"]]
    .rename(columns={"Unnamed: 0": "query_id"})
    .assign(
        csmpo_mean=csmpo_df["csmpo_mean"].values,
        csmso_mean=csmso_df["csmso_mean"].values,
        mipo_mean=mipo_df["mipo_mean"].values,
        miso_mean=miso_df["miso_mean"].values,
    )
)

# %%
final_df
# Out:
#     query_id                                              query  \
# 0          0                       What is the best smartphone?
# 1          1    What is the best smartphone under 1000 dollars?
# 2          2  What is the best smartphone under 1000 dollars...
# 3          3  What is the best smartphone under 1000 dollars...
# 4          4                           What is the best laptop?
# 5          5        What is the best laptop under 1500 dollars?
# 6          6  What is the best laptop under 1500 dollars wit...
# 7          7  What is the best laptop under 1500 dollars wit...
# 8          8                       What is the best smartwatch?
# 9          9     What is the best smartwatch under 800 dollars?
# 10        10  What is the best smartwatch under 800 dollars ...
# 11        11  What is the best smartwatch under 800 dollars ...
# 12        12                      What are the best headphones?
# 13        13    What are the best headphones under 500 dollars?
# 14        14  What are the best headphones under 500 dollars...
# 15        15  What are the best headphones under 500 dollars...
# 16        16                            What is the best drone?
# 17        17         What is the best drone under 3000 dollars?
# 18        18  What is the best drone under 3000 dollars with...
# 19        19  What is the best drone under 3000 dollars with...
# 20        20                       What is the best 3d printer?
# 21        21    What is the best 3d printer under 2000 dollars?
# 22        22  What is the best 3d printer under 2000 dollars...
# 23        23  What is the best 3d printer under 2000 dollars...
# 24        24                       What is the best vr headset?
# 25        25    What is the best vr headset under 1000 dollars?
# 26        26  What is the best vr headset under 1000 dollars...
# 27        27  What is the best vr headset under 1000 dollars...
# 28        28               What is the best portable projector?
# 29        29  What is the best portable projector under 2500...
# 30        30  What is the best portable projector under 2500...
# 31        31  What is the best portable projector under 2500...
# 32        32                     What is the best electric car?
# 33        33  What is the best electric car under 50000 doll...
# 34        34  What is the best electric car under 50000 doll...
# 35        35  What is the best electric car under 50000 doll...
# 36        36                 What is the best electric bicycle?
# 37        37  What is the best electric bicycle under 7500 d...
# 38        38  What is the best electric bicycle under 7500 d...
# 39        39  What is the best electric bicycle under 7500 d...
# 40        40                    What is the best digital piano?
# 41        41  What is the best digital piano under 5000 doll...
# 42        42  What is the best digital piano under 5000 doll...
# 43        43  What is the best digital piano under 5000 doll...
# 44        44                     What is the best refrigerator?
# 45        45  What is the best refrigerator under 5000 dollars?
# 46        46  What is the best refrigerator under 5000 dolla...
# 47        47  What is the best refrigerator under 5000 dolla...
#
#                      market_type                          query_level  \
# 0          Commodity / Saturated                              General
# 1          Commodity / Saturated                      General & Price
# 2          Commodity / Saturated            General & Price & Feature
# 3          Commodity / Saturated  General & Price & Feature & Feature
# 4          Commodity / Saturated                              General
# 5          Commodity / Saturated                      General & Price
# 6          Commodity / Saturated            General & Price & Feature
# 7          Commodity / Saturated  General & Price & Feature & Feature
# 21          3D Printer    0.077659    0.066667   0.574074   0.555556
# 22          3D Printer    0.098089    0.333333   0.555556   0.222222
# 23          3D Printer    0.121746    0.083333   0.449074   0.416667
# 24          VR Headset    0.739325    0.442857   0.875000   0.600000
# 25          VR Headset    0.239683    0.000000   0.541667   0.500000
# 26          VR Headset    0.298016    0.000000   0.791667   0.587302
# 27          VR Headset    0.250278    0.000000   0.595238   0.416667
# 28  Portable Projector    0.151362    0.166667   0.842593   0.666667
# 29  Portable Projector    0.104690    0.000000   0.333333   0.777778
# 30  Portable Projector    0.036429    0.000000   0.000000   0.000000
# 31  Portable Projector    0.084524    0.000000   0.166667   0.000000
# 32        Electric Car    0.298611    0.355556   0.777778   0.633333
# 33        Electric Car    0.282222    0.222222   0.766667   0.250000
# 34        Electric Car    0.372222    0.411111   0.566667   0.850000
# 35        Electric Car    0.227619    0.041667   0.633333   0.700000
# 36    Electric Bicycle    0.127357    0.300000   0.377778   0.933333
# 37    Electric Bicycle    0.110648    0.666667   0.166667   0.333333
# 38    Electric Bicycle    0.094444    0.333333   0.245370   0.000000
# 39    Electric Bicycle    0.084722    0.111111   0.083333   0.166667
# 40       Digital Piano    0.313754    0.400000   0.866667   0.416667
# 41       Digital Piano    0.219749    0.555556   0.359259   0.500000
# 42       Digital Piano    0.170796    0.111111   0.333333   0.833333
# 43       Digital Piano    0.219907    0.111111   0.333333   0.000000
# 44        Refrigerator    0.110238    0.277778   0.250000   0.694444
# 45        Refrigerator    0.000000    0.000000   0.416667   1.000000
# 46        Refrigerator    0.000000    0.166667   0.166667   0.000000
# 47        Refrigerator    0.000000    0.083333   0.166667   0.305556

# %%
from scipy.stats import kruskal

def create_statistical_summary_table(results_df):
    
    metrics = ["csmpo_mean", "csmso_mean", "mipo_mean", "miso_mean"]
    groupings = ["market_type", "query_level"]
    
    summary_data = []
    
    for metric in metrics:
        for grouping in groupings:
            # Get groups
            groups = []
            group_names = results_df[grouping].unique()
            
            for group_name in group_names:
                group_data = results_df[results_df[grouping] == group_name][metric].dropna()
                if len(group_data) > 0:
                    groups.append(group_data)
            
            # Perform Kruskal-Wallis test
            if len(groups) >= 2:
                H, p = kruskal(*groups)
                
                summary_data.append({
                    "Metric": metric,
                    "Comparison": grouping.replace("_", " ").title(),
                    "H-statistic": f"{H:.2f}",
                    "p-value": f"{p:.3f}" if p >= 0.001 else "< 0.001",
                    "Significant": "Yes*" if p < 0.05 else "No"
                })
    
    summary_df = pd.DataFrame(summary_data)
    
    return summary_df

# %%
create_statistical_summary_table(final_df)
# Out:
#        Metric   Comparison H-statistic p-value Significant
# 0  csmpo_mean  Market Type        2.14   0.343          No
# 1  csmpo_mean  Query Level        9.40   0.024        Yes*
# 2  csmso_mean  Market Type        4.98   0.083          No
# 3  csmso_mean  Query Level       15.66   0.001        Yes*
# 4   mipo_mean  Market Type        3.23   0.199          No
# 5   mipo_mean  Query Level        8.00   0.046        Yes*
# 6   miso_mean  Market Type        1.09   0.579          No
# 7   miso_mean  Query Level       15.62   0.001        Yes*
